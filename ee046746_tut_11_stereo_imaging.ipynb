# %% [markdown]
# # <img src="https://img.icons8.com/bubbles/100/000000/3d-glasses.png" style="height:50px;display:inline"> EE 046746 - Technion - Computer Vision
#
# #### Elias Nehme
#
# ## Tutorial 11 - Stereo Imaging
# ---

# %% [markdown]
# ## <img src="https://img.icons8.com/bubbles/50/000000/checklist.png" style="height:50px;display:inline"> Agenda
# ---
# * [Triangulation](#-Triangulation)
# * [Stereo Concept](#-Stereo-Concept)
# * [Stereo Rectification](#-Stereo-Rectification)
# * [Stereo Matching](#-Stereo-Matching)
#     * [Depth Smoothing](#-Depth-Smoothing)
# * [Code Example](#-Code-Example)
# * [Recommended Videos](#-Recommended-Videos)
# * [Credits](#-Credits)

# %% [markdown]
# ## <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Triangulation
# ---

# %% [markdown]
# ### <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Reconstructing 3D points
# ---
#
# <img src="./assets/stereo_tri1.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Reconstructing 3D points
# ---
#
# <img src="./assets/stereo_tri2.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Reconstructing 3D points
# ---
#
# <img src="./assets/stereo_tri3.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Reconstructing 3D points
# ---
#
# <img src="./assets/stereo_tri4.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Reconstructing 3D points
# ---
#
# <img src="./assets/stereo_tri5.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Reconstructing 3D points
# ---
#
# * Switch to row-wise representation of the projection matrix:
# $$ \begin{bmatrix} x \\ y  \\ 1 \end{bmatrix} = \begin{bmatrix} m_{11} & m_{12} & m_{13} & m_{14}\\ m_{21} & m_{22} & m_{23} & m_{24} \\ m_{31} & m_{32} & m_{33} & m_{34} \end{bmatrix}
# \begin{bmatrix} X \\ Y  \\ Z \\ 1  \end{bmatrix} \leftrightarrow \begin{bmatrix} x \\ y  \\ 1 \end{bmatrix} = \begin{bmatrix} - & m_1^T & - \\ - & m_2^T & - \\ - & m_3^T & - \end{bmatrix} P$$
#
# * Use the fact that the cross product should be zero:
# $$ p \times M P = 0 $$

# %% [markdown]
# ### <img src="https://img.icons8.com/color/48/000000/3d-scale.png" style="height:50px;display:inline"> Reconstructing 3D points
# ---
#
# * Leads to two independent equations:
#
# $$ p \times M P = 0 \rightarrow \begin{bmatrix} y m_3^T P - m_2^T P \\ m_1^T P - x m_3^T P \end{bmatrix} = 0$$
#
# * Using the matched point in image 2 as well $\rightarrow$ Solution by SVD:
#
# $$ \begin{bmatrix} y m_3^T - m_2^T \\ m_1^T - x m_3^T \\ \tilde{y} \tilde{m}_3^T - \tilde{m}_2^T \\ \tilde{m}_1^T - \tilde{x} \tilde{m}_3^T \end{bmatrix} P = 0 \leftrightarrow A P = 0$$

# %% [markdown]
# ## <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Stereo Concept
# ---

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept1.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept2.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept3.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept4.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept6.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept7.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept8.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept9.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept10.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept11.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept12.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept13.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept14.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept16.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/doodle/48/000000/3d-glasses.png" style="height:50px;display:inline"> Depth vs Disparity
# ---
#
# <img src="./assets/stereo_concept16.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/advance.png" style="height:50px;display:inline"> Depth vs Disparity: Application 1
# ---
#
# <img src="./assets/stereo_app1.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/advance.png" style="height:50px;display:inline"> Depth vs Disparity: Application 1
# ---
#
# <img src="./assets/stereo_app2.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/advance.png" style="height:50px;display:inline"> Depth vs Disparity: Intuition?
# ---
#
# <img src="./assets/stereo_humanvis1.png" width="600">
#
# * <a href="https://medium.com/@omar.ps16/stereo-3d-reconstruction-with-opencv-using-an-iphone-camera-part-iii-95460d3eddf0">Image Source</a>

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/advance.png" style="height:50px;display:inline"> Depth vs Disparity: Application 2
# ---
#
# <img src="./assets/stereo_app3.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/advance.png" style="height:50px;display:inline"> Depth vs Disparity: Application 2
# ---
#
# <img src="./assets/stereo_app5.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/advance.png" style="height:50px;display:inline"> Depth vs Disparity: Application 2
# ---
#
# <img src="./assets/stereo_app6.jpg" width="800">

# %% [markdown]
# ## <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect1.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect2.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# * What is special about these two cameras?
#     * they have the same image plane: No rotation, only horizontal translation.
#
# <img src="./assets/stereo_concept7.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect4.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect6.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect7.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect8.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect9.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect10.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect11.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect12.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect13.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect15.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect16.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/material-two-tone/64/000000/stack-of-photos.png" style="height:50px;display:inline"> Stereo Rectification
# ---
#
# <img src="./assets/stereo_rect17.jpg" width="800">
#
# * OpenCV got you covered with `cv2.stereoRectify()`...

# %% [markdown]
# ## <img src="https://img.icons8.com/wired/64/000000/solve.png" style="height:50px;display:inline"> Stereo Matching
# ---

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/solve.png" style="height:50px;display:inline"> Stereo Matching
# ---
#
# <img src="./assets/stereo_match1.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/solve.png" style="height:50px;display:inline"> Stereo Matching
# ---
#
# <img src="./assets/stereo_match2.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/solve.png" style="height:50px;display:inline"> Stereo Matching
# ---
#
# <img src="./assets/stereo_match3.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/solve.png" style="height:50px;display:inline"> Stereo Matching
# ---
#
# <img src="./assets/stereo_match4.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/solve.png" style="height:50px;display:inline"> Stereo Matching
# ---
#
# <img src="./assets/stereo_match5.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/solve.png" style="height:50px;display:inline"> Stereo Matching
# ---
#
# <img src="./assets/stereo_match6.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match7.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match8.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match9.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match10.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match12.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match13.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match14.jpg" width="800">

# %% [markdown]
# ### <img src="https://img.icons8.com/wired/64/000000/iron.png" style="height:50px;display:inline"> Depth Smoothing
# ---
#
# <img src="./assets/stereo_match11.jpg" width="800">

# %% [markdown]
# ## <img src="https://img.icons8.com/color/96/000000/code.png" style="height:50px;display:inline"> Code Example
# * Code based on example by <a href="https://github.com/opencv/opencv/blob/master/samples/python/stereo_match.py">OpenCV</a>

# %% [markdown]
# ### <img src="https://img.icons8.com/color/96/000000/code.png" style="height:50px;display:inline"> Point Cloud from Stereo Images
# ---
# * Resulting `.ply` file can be easily viewed using <a href="http://meshlab.sourceforge.net/">MeshLab</a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# function that writes a disparity to a point cloud
def write_ply(fn, verts, colors):
    ply_header = '''ply
    format ascii 1.0
    element vertex %(vert_num)d
    property float x
    property float y
    property float z
    property uchar red
    property uchar green
    property uchar blue
    end_header
    '''
    verts = verts.reshape(-1, 3)
    colors = colors.reshape(-1, 3)
    verts = np.hstack([verts, colors])
    with open(fn, 'wb') as f:
        f.write((ply_header % dict(vert_num=len(verts))).encode('utf-8'))
        np.savetxt(f, verts, fmt='%f %f %f %d %d %d ')

# %%
# load the input images and downscale for faster processing
imgL = cv2.pyrDown(cv2.imread('./assets/aloeL.jpg'))
imgR = cv2.pyrDown(cv2.imread('./assets/aloeR.jpg'))

# load also the GT depth for comparison
disp_gt = cv2.pyrDown(cv2.imread('./assets/aloeGT.png'))

# look at the inputs
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(cv2.cvtColor(imgL,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Left Image', fontsize=30)
plt.subplot(122)
plt.imshow(cv2.cvtColor(imgR,cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Right Image', fontsize=30)
plt.show()

# %%
# disparity range is tuned for 'aloe' image pair
window_size = 3
min_disp = 16
num_disp = 112-min_disp
stereo = cv2.StereoSGBM_create(minDisparity = min_disp,
    numDisparities = num_disp,
    blockSize = 16,
    P1 = 8*3*window_size**2,
    P2 = 32*3*window_size**2,
    disp12MaxDiff = 1,
    uniquenessRatio = 10,
    speckleWindowSize = 100,
    speckleRange = 32
)

# compute the disparity using opencv func.
disp = stereo.compute(imgL, imgR).astype(np.float32) / 16.0

# %%
# compare the result to the ground truth
# look at the inputs
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow((disp-min_disp)/num_disp, cmap='gray')
plt.axis('off')
plt.title('Estimated Disparity', fontsize=30)
plt.subplot(122)
plt.imshow(cv2.cvtColor(disp_gt,cv2.COLOR_BGR2GRAY), cmap='gray')
plt.axis('off')
plt.title('GT Disparity', fontsize=30)
plt.show()

# %%
# generate a colored 3D point cloud by reprojecting to 3D for Meshlab
print('generating 3d point cloud...',)
h, w = imgL.shape[:2]
f = 0.8*w                          # guess for focal length
Q = np.float32([[1, 0, 0, -0.5*w],
                [0,-1, 0,  0.5*h], # turn points 180 deg around x-axis,
                [0, 0, 0,     -f], # so that y-axis looks up
                [0, 0, 1,      0]])
points = cv2.reprojectImageTo3D(disp, Q)
colors = cv2.cvtColor(imgL, cv2.COLOR_BGR2RGB)
mask = disp > disp.min()
out_points = points[mask]
out_colors = colors[mask]
out_fn = 'out.ply'
write_ply(out_fn, out_points, out_colors)
print('%s saved' % out_fn)
# Out:
# generating 3d point cloud...
# out.ply saved

# %% [markdown]
# ### <img src="https://img.icons8.com/bubbles/50/000000/video-playlist.png" style="height:50px;display:inline"> Recommended Videos
# ---
# #### <img src="https://img.icons8.com/cute-clipart/64/000000/warning-shield.png" style="height:30px;display:inline"> Warning!
# * These videos do not replace the lectures and tutorials.
# * Please use these to get a better understanding of the material, and not as an alternative to the written material.
#
# #### Video By Subject
# * Student Competition - <a href="https://www.youtube.com/watch?v=GpU1Vx-b3VA&ab_channel=MATLABMATLAB">Computer Vision Training</a>
# * CVFX Lecture 15 - <a href="https://www.youtube.com/watch?v=kxsvG4sSuvA&ab_channel=ComputerphileComputerphileVerified">Stereo Correspondence</a>

# %% [markdown]
# ## <img src="https://img.icons8.com/dusk/64/000000/prize.png" style="height:50px;display:inline"> Credits
# ----
# * Slides (CMU) - <a href="https://www.cs.cmu.edu/~igkioule/">Ioannis Gkioulekas</a>, <a href="http://www.cs.cmu.edu/~kkitani/">Kris Kitani</a>, <a href="http://www.cs.cmu.edu/~srinivas/">Srinivasa Narasimhan</a>
# * Multiple View Geometry in Computer Vision - Hartley and Zisserman - Chapter 6
# * <a href="http://www.computervisionmodels.com/">Computer vision: models, learning and inference</a> , Simon J.D. Prince - Chapter 15
# * <a href="https://www.springer.com/gp/book/9781848829343">Computer Vision: Algorithms and Applications</a> - Richard Szeliski - Sections 2.1.5, 6.2. , 7.1, 7.2, 11.1
#
# * Icons from <a href="https://icons8.com/">Icon8.com</a> - https://icons8.com
